# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# Merging 12 months of data into a signle file
from os import listdir
from os.path import isfile, join

mypath='./Sales_Data/'
files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
all_months_data=pd.DataFrame()
lines=0

myorder=[8,2,3,1,5,11,10,4,9,7,6,0]
ordered_months = files
ordered_months = [ordered_months[i] for i in myorder]

for i in ordered_months:
    temp_=pd.read_csv(mypath+i)
    all_months_data=pd.concat([all_months_data,temp_])
    lines=lines+(temp_.count())
    
all_months_data.to_csv('all_data.csv',index=False)
# Out:
# files: ['Sales_December_2019.csv', 'Sales_April_2019.csv', 'Sales_February_2019.csv', 'Sales_March_2019.csv', 'Sales_August_2019.csv', 'Sales_May_2019.csv', 'Sales_November_2019.csv', 'Sales_October_2019.csv', 'Sales_January_2019.csv', 'Sales_September_2019.csv', 'Sales_July_2019.csv', 'Sales_June_2019.csv']
#
# orderedmonths: ['Sales_January_2019.csv', 'Sales_February_2019.csv', 'Sales_March_2019.csv', 'Sales_April_2019.csv', 'Sales_May_2019.csv', 'Sales_June_2019.csv', 'Sales_July_2019.csv', 'Sales_August_2019.csv', 'Sales_September_2019.csv', 'Sales_October_2019.csv', 'Sales_November_2019.csv', 'Sales_December_2019.csv']
#
# lines : 9697
#
# lines : 21701
#
# lines : 36890
#
# lines : 55214
#
# lines : 71801
#
# lines : 85380
#
# lines : 99706
#
# lines : 111689
#
# lines : 123335
#
# lines : 143652
#
# lines : 161268
#
# lines : 186305
#       Order ID                     Product Quantity Ordered Price Each  \
# ...

# %%
all_data=pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [raw]
#  Best Month for sales? Earnings?
