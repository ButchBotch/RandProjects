# %%
import pandas as pd

# Read CSV
df=pd.read_csv('pokemon_datacsv.csv')
print(df.head()) # tail(50) to see last 50 rows

# Read .xlsx
# df_xlsx=pd.read_excel('pokemon_data.xlsx')
# Read .txt
# df_txt=pd.read_csv('pokemon_data.txt',delimiter='\t')
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print('columns :\n' ,df.columns)
#print(df['Name','Type 1']) # alternatively df.Name

# Read each row
print('\niloc:\n',df.iloc[0:5])

# read specific location(r,c)
print('\nelement (2,1):\n',df.iloc[2,1],'\n')

#for index,row in df.iterrows():
#    print(index,row['Name']) #or row.Name

#print('\nFire:\n',df.loc[df['Type 1']=='Fire'& df.loc[df['#']<100]]) #Grass whatever
q1=df.loc[df['Type 1']=='Fire']
q2=q1.loc[q1['#']<100]
print('q1:\n',q1,'\n\n\nq2:\n',q2)
#df.describe to see some random shit like mean std etc.
# Out:
# columns :
#  Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#
# iloc:
#     #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# element (2,1):
#  Venusaur
#
# q1:
#         #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# 135  126                     Magmar   Fire       NaN   65      95       57
# 147  136                    Flareon   Fire       NaN   65     130       60
# 158  146                    Moltres   Fire    Flying   90     100       90
# 169  155                  Cyndaquil   Fire       NaN   39      52       43
# 170  156                    Quilava   Fire       NaN   58      64       58
# 171  157                 Typhlosion   Fire       NaN   78      84       78
# 236  218                     Slugma   Fire       NaN   40      40       40
# 237  219                   Magcargo   Fire      Rock   50      50      120
# 259  240                      Magby   Fire       NaN   45      75       37
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 276  255                    Torchic   Fire       NaN   45      60       40
# 277  256                  Combusken   Fire  Fighting   60      85       60
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 352  322                      Numel   Fire    Ground   60      60       40
# 353  323                   Camerupt   Fire    Ground   70     100       70
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 355  324                    Torkoal   Fire       NaN   70      85      140
# 435  390                   Chimchar   Fire       NaN   44      58       44
# 436  391                   Monferno   Fire  Fighting   64      78       52
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 518  467                  Magmortar   Fire       NaN   75      95       67
# 542  485                    Heatran   Fire     Steel   91      90      106
# 557  498                      Tepig   Fire       NaN   65      63       45
# 558  499                    Pignite   Fire  Fighting   90      93       55
# 559  500                     Emboar   Fire  Fighting  110     123       65
# 572  513                    Pansear   Fire       NaN   50      53       48
# 573  514                   Simisear   Fire       NaN   75      98       63
# 614  554                   Darumaka   Fire       NaN   70      90       45
# 615  555    DarmanitanStandard Mode   Fire       NaN  105     140       55
# 616  555         DarmanitanZen Mode   Fire   Psychic  105      30      105
# 692  631                    Heatmor   Fire       NaN   85      97       66
# 721  653                   Fennekin   Fire       NaN   40      45       40
# 722  654                    Braixen   Fire       NaN   59      59       58
# 723  655                    Delphox   Fire   Psychic   75      69       72
# 730  662                Fletchinder   Fire    Flying   62      73       55
# 731  663                 Talonflame   Fire    Flying   78      81       71
# 735  667                     Litleo   Fire    Normal   62      50       58
# 736  668                     Pyroar   Fire    Normal   86      68       72
# 799  721                  Volcanion   Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         60       50     65           1      False
# 5         80       65     80           1      False
# 6        109       85    100           1      False
# 7        130       85    100           1      False
# 8        159      115    100           1      False
# 42        50       65     65           1      False
# 43        81      100    100           1      False
# 63        70       50     60           1      False
# 64       100       80     95           1      False
# 83        65       65     90           1      False
# 84        80       80    105           1      False
# 135      100       85     93           1      False
# 147       95      110     65           1      False
# 158      125       85     90           1       True
# 169       60       50     65           2      False
# 170       80       65     80           2      False
# 171      109       85    100           2      False
# 236       70       40     20           2      False
# 237       80       80     30           2      False
# 259       70       55     83           2      False
# 263       90       75    100           2       True
# 270      110      154     90           2       True
# 276       70       50     45           3      False
# 277       85       60     55           3      False
# 278      110       70     80           3      False
# 279      130       80    100           3      False
# 352       65       45     35           3      False
# 353      105       75     40           3      False
# 354      145      105     20           3      False
# 355       85       70     20           3      False
# 435       58       44     61           4      False
# 436       78       52     81           4      False
# 437      104       71    108           4      False
# 518      125       95     83           4      False
# 542      130      106     77           4       True
# 557       45       45     45           5      False
# 558       70       55     55           5      False
# 559      100       65     65           5      False
# 572       53       48     64           5      False
# 573       98       63    101           5      False
# 614       15       45     50           5      False
# 615       30       55     95           5      False
# 616      140      105     55           5      False
# 692      105       66     65           5      False
# 721       62       60     60           6      False
# 722       90       70     73           6      False
# 723      114      100    104           6      False
# 730       56       52     84           6      False
# 731       74       69    126           6      False
# 735       73       54     72           6      False
# 736      109       66    106           6      False
# 799      130       90     70           6       True
#
#
# q2:
#       #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
# 43  38                  Ninetales   Fire     NaN  73      76       75
# 63  58                  Growlithe   Fire     NaN  55      70       45
# 64  59                   Arcanine   Fire     NaN  90     110       80
# 83  77                     Ponyta   Fire     NaN  50      85       55
# 84  78                   Rapidash   Fire     NaN  65     100       70
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 42       50       65     65           1      False
# 43       81      100    100           1      False
# 63       70       50     60           1      False
# 64      100       80     95           1      False
# 83       65       65     90           1      False
# 84       80       80    105           1      False

# %%
df.sort_values(['Type 1','HP','Name'],ascending=[1,1,0])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# 316     40           3      False
# 230      5           2      False
# 603     57           5      False
# 462     70           4      False
# 314     40           3      False
# ..     ...         ...        ...
# 350     60           3      False
# 145     65           1      False
# 142     60           1      False
# 655     65           5      False
# 351     60           3      False
#
# [800 rows x 12 columns]

# %%
df['Total'] = 2*df['HP'] + 1.5*df['Attack'] + 1.5*df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + 0.8*df['Speed']
akak=df.sort_values('Total', ascending=False)
print('MyTotal:\n',akak.head(30))
# df.drop(columns=['Total']) # DROP COLUMN??
df['Total2']=df.iloc[:,4:10].sum(axis=1)
kaka=df.sort_values('Total2', ascending=False)
print('\n\n\nBasicTotal:\n',kaka.head(30))
# Out:
# MyTotal:
#         #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 422  382      KyogrePrimal Kyogre    Water       NaN  100     150       90
# 164  150      MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 711  646       KyuremBlack Kyurem   Dragon       Ice  125     170      100
# 552  493                   Arceus   Normal       NaN  120     120      120
# 494  445    GarchompMega Garchomp   Dragon    Ground  108     170      115
# 313  289                  Slaking   Normal       NaN  150     160      100
# 545  487     GiratinaOrigin Forme    Ghost    Dragon  150     120      100
# 544  487    GiratinaAltered Forme    Ghost    Dragon  150     100      120
# 712  646       KyuremWhite Kyurem   Dragon       Ice  125     120       90
# 409  373  SalamenceMega Salamence   Dragon    Flying   95     145      130
# 413  376  MetagrossMega Metagross    Steel   Psychic   80     145      150
# 792  716                  Xerneas    Fairy       NaN  126     131       95
# 793  717                  Yveltal     Dark    Flying  126     131       95
# 707  644                   Zekrom   Dragon  Electric  100     150      120
# 423  383                  Groudon   Ground       NaN  100     150      140
# 543  486                Regigigas   Normal       NaN  110     160      110
# 425  384                 Rayquaza   Dragon    Flying  105     150       90
# 540  483                   Dialga    Steel    Dragon  100     120      120
# 270  250                    Ho-oh     Fire    Flying  106     130       90
# 710  646                   Kyurem   Dragon       Ice  125     130       90
# 333  306        AggronMega Aggron    Steel       NaN   70     140      230
# 269  249                    Lugia  Psychic    Flying  106      90      130
# 420  381        LatiosMega Latios   Dragon   Psychic   80     130      100
# 706  643                 Reshiram   Dragon      Fire  100     120      100
# 418  380        LatiasMega Latias   Dragon   Psychic   80     100      120
# 796  719      DiancieMega Diancie     Rock     Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary   Total  Total2
# 424      150       90     90           3       True  1022.0     770
# 163      154      100    130           1       True  1005.0     780
# 426      180      100    115           3       True  1002.0     780
# 422      180      160     90           3       True   972.0     770
# 164      194      120    140           1       True   968.0     780
# 268       95      120     71           2      False   942.8     700
# 711      120       90     95           5       True   941.0     700
# 552      120      120    120           4       True   936.0     720
# 494      120       95     92           4      False   932.1     700
# 313       95       65    100           3      False   930.0     670
# 545      120      100     90           4       True   922.0     680
# 544      100      120     90           4       True   922.0     680
# 712      170      100     95           5       True   911.0     700
# 409      120       90    120           3      False   908.5     700
# 413      105      110    110           3      False   905.5     700
# 792      131       98     99           6       True   899.2     680
# 793      131       98     99           6       True   899.2     680
# 707      120      100     90           5       True   897.0     680
# 423      100       90     90           3       True   897.0     670
# 543       80      110    100           4       True   895.0     670
# 425      150       90     95           3       True   886.0     680
# 540      150      100     90           4       True   882.0     680
# 270      110      154     90           2       True   878.0     680
# 710      130       90     95           5       True   876.0     660
# 333       60       80     50           3      False   875.0     630
# 269       90      154    110           2       True   874.0     680
# 420      160      120    110           3       True   873.0     700
# 706      150      120     90           5       True   872.0     680
# 418      140      150    110           3       True   868.0     700
# 796      160      110    110           6       True   863.0     700
#
#
#
# BasicTotal:
#         #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150      MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382      KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 552  493                   Arceus   Normal       NaN  120     120      120
# 712  646       KyuremWhite Kyurem   Dragon       Ice  125     120       90
# 711  646       KyuremBlack Kyurem   Dragon       Ice  125     170      100
# 409  373  SalamenceMega Salamence   Dragon    Flying   95     145      130
# 413  376  MetagrossMega Metagross    Steel   Psychic   80     145      150
# 418  380        LatiasMega Latias   Dragon   Psychic   80     100      120
# 420  381        LatiosMega Latios   Dragon   Psychic   80     130      100
# 494  445    GarchompMega Garchomp   Dragon    Ground  108     170      115
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 796  719      DiancieMega Diancie     Rock     Fairy   50     160      110
# 425  384                 Rayquaza   Dragon    Flying  105     150       90
# 545  487     GiratinaOrigin Forme    Ghost    Dragon  150     120      100
# 544  487    GiratinaAltered Forme    Ghost    Dragon  150     100      120
# 707  644                   Zekrom   Dragon  Electric  100     150      120
# 541  484                   Palkia    Water    Dragon   90     120      100
# 540  483                   Dialga    Steel    Dragon  100     120      120
# 270  250                    Ho-oh     Fire    Flying  106     130       90
# 269  249                    Lugia  Psychic    Flying  106      90      130
# 706  643                 Reshiram   Dragon      Fire  100     120      100
# 792  716                  Xerneas    Fairy       NaN  126     131       95
# 798  720       HoopaHoopa Unbound  Psychic      Dark   80     160       60
# 162  150                   Mewtwo  Psychic       NaN  106     110       90
# 793  717                  Yveltal     Dark    Flying  126     131       95
# 543  486                Regigigas   Normal       NaN  110     160      110
# 423  383                  Groudon   Ground       NaN  100     150      140
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary   Total  Total2
# 426      180      100    115           3       True  1002.0     780
# 164      194      120    140           1       True   968.0     780
# 163      154      100    130           1       True  1005.0     780
# 422      180      160     90           3       True   972.0     770
# 424      150       90     90           3       True  1022.0     770
# 552      120      120    120           4       True   936.0     720
# 712      170      100     95           5       True   911.0     700
# 711      120       90     95           5       True   941.0     700
# 409      120       90    120           3      False   908.5     700
# 413      105      110    110           3      False   905.5     700
# 418      140      150    110           3       True   868.0     700
# 420      160      120    110           3       True   873.0     700
# 494      120       95     92           4      False   932.1     700
# 268       95      120     71           2      False   942.8     700
# 796      160      110    110           6       True   863.0     700
# 425      150       90     95           3       True   886.0     680
# 545      120      100     90           4       True   922.0     680
# 544      100      120     90           4       True   922.0     680
# 707      120      100     90           5       True   897.0     680
# 541      150      120    100           4       True   860.0     680
# 540      150      100     90           4       True   882.0     680
# 270      110      154     90           2       True   878.0     680
# 269       90      154    110           2       True   874.0     680
# 706      150      120     90           5       True   872.0     680
# 792      131       98     99           6       True   899.2     680
# 798      170      130     80           6       True   854.0     680
# 162      154       90    130           1       True   860.0     680
# 793      131       98     99           6       True   899.2     680
# 543       80      110    100           4       True   895.0     670
# 423      100       90     90           3       True   897.0     670

# %%
# rearranging the table
cols=list(df.columns.values)
df3=df.copy()
df3=df3[cols[0:4]+[cols[-2]]+cols[4:12]]
print(df3)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  403.0  45      49       49
# 1      2                Ivysaur    Grass  Poison  515.5  60      62       63
# 2      3               Venusaur    Grass  Poison  671.5  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  800.5  80     100      123
# 4      4             Charmander     Fire     NaN  382.5  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  765.0  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  863.0  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  751.0  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  854.0  80     160       60
# 799  721              Volcanion     Fire   Water  781.0  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#save to csv excel txt
df3.to_csv('modified.csv',index=False) #df3.to_excel('modfied.xlsx',index=False)
df3.to_csv('modified.txt',index=False, sep='\t')

# %%
new_df=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df.HP>60)]
new_df.to_csv('grasshp.csv')
newst_df=new_df.reset_index(drop=True)
print(newst_df)
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   70             Weepinbell  Grass  Poison   65      90       50       85
# 4   71             Victreebel  Grass  Poison   80     105       65      100
# 5  590                Foongus  Grass  Poison   69      55       45       55
# 6  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total  Total2
# 0      100     80           1      False  671.5     525
# 1      120     80           1      False  800.5     625
# 2       90     50           1      False  637.5     490
# 3       45     55           1      False  514.0     390
# 4       70     70           1      False  641.0     490
# 5       55     15           5      False  410.0     294
# 6       80     30           5      False  649.5     464

# %%
import re

df4=df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
df4=df.loc[df['Name'].str.contains('^pi[A-Z]*', flags=re.I, regex=True)]
print(df4)
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# 578  519               Pidove    Normal    Flying   50      55       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total  Total2
# 20        35       35     56           1      False  322.3     251
# 21        50       50     71           1      False  455.3     349
# 22        70       70    101           1      False  619.3     479
# 23       135       80    121           1      False  717.8     579
# 30        50       50     90           1      False  384.5     320
# 136       55       70     85           1      False  660.5     500
# 137       65       90    105           1      False  781.5     600
# 186       35       35     60           2      False  240.5     205
# 219       35       35     15           2      False  414.5     290
# 239       60       60     50           2      False  630.0     450
# 438       61       56     40           4      False  411.0     314
# 558       70       55     55           5      False  571.0     418
# 578       36       30     43           5      False  357.9     264

# %%
df_flamer.loc[df_flamer['Type 1']=='Fire','Type 1'] ='Flamer'
df_flamer.loc[df_flamer['Total']>500, ['Generation','Legendary']]=['X','Loco']
print(df_flamer)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Total  Total2
# 0         65       65     45          1     False  403.0     318
# 1         80       80     60          X      Loco  515.5     405
# 2        100      100     80          X      Loco  671.5     525
# 3        122      120     80          X      Loco  800.5     625
# 4         60       50     65          1     False  382.5     309
# ..       ...      ...    ...        ...       ...    ...     ...
# 795      100      150     50          X      Loco  765.0     600
# 796      160      110    110          X      Loco  863.0     700
# 797      150      130     70          X      Loco  751.0     600
# 798      170      130     80          X      Loco  854.0     680
# 799      130       90     70          X      Loco  781.0     600
#
# [800 rows x 14 columns]

# %%
df=pd.read_csv('modified.csv')
#df.groupby(['Type 1']).mean().sort_values('Total', ascending=False) # can sum() instead of mean
df['count']=1
groupby=df.groupby(['Type 1','Type 2']).count()['count']
print(groupby)
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
#count ow many in each type
